# %%
import pandas as pd
import json

# %%
df = pd.read_csv('Datasets\survery_1.csv', sep=',')
df.head()
# Out:
#             Timestamp How old are you? What industry do you work in?  \
# 0  4/24/2019 11:43:21            35-44                    Government
# 1  4/24/2019 11:43:26            25-34       Environmental nonprofit
# 2  4/24/2019 11:43:27            18-24               Market Research
# 3  4/24/2019 11:43:27            25-34                 Biotechnology
# 4  4/24/2019 11:43:29            25-34                    Healthcare
#
#                                   Job title What is your annual salary?  \
# 0          Talent Management Asst. Director                       75000
# 1                       Operations Director                      65,000
# 2                 Market Research Assistant                      36,330
# 3                          Senior Scientist                       34600
# 4  Social worker (embedded in primary care)                       55000
#
#   Please indicate the currency Where are you located? (City/state/country)  \
# ...

# %%
df2 = pd.read_csv('Datasets\survery_2.csv', sep=',')
df2.head()
# Out:
#            Timestamp Employment Type     Company Name  \
# 0  9/11/2019 0:47:40       Full-time             Citi
# 1  9/11/2019 0:51:26       Full-time              Ibm
# 2  9/11/2019 0:51:56       Full-time        No Answer
# 3  9/11/2019 0:52:28       Full-time    Td ameritrade
# 4  9/11/2019 0:54:02       Full-time  The Table Times
#
#   Company Size - # Employees Primary Location (Country)  \
# 0             10,000-100,000         United States (US)
# 1             10,000-100,000         United States (US)
# 2             10,000-100,000             Australia (AU)
# 3               1,000-10,000         United States (US)
# 4                     20-100         United States (US)
#
#   Primary Location (City)         Industry in Company  \
# 0               Manhattan                     Finance
# 1                     NaN                    Software
# 2                     NaN         General Engineering
# 3               Ann arbor             Web Development
# ...

# %%
df3 = pd.read_csv('Datasets\survery_3.csv', sep=',')
df3.head()
# Out:
#             Timestamp            Employer           Location  \
# 0  3/21/2016 12:54:49                 NaN        Raleigh, NC
# 1  3/21/2016 12:58:52              Opower  San Francisco, CA
# 2  3/21/2016 12:58:57                 NaN       San Diego CA
# 3  3/21/2016 12:58:58             Walmart    Bentonville, AR
# 4  3/21/2016 12:59:11  Vertical Knowledge      Cleveland, OH
#
#             Job Title Years at Employer Years of Experience Annual Base Pay  \
# 0  Software Developer               NaN                  18          122000
# 1    Systems Engineer                 2                  13          125000
# 2    Systems engineer                 1     1 of employment          83,000
# 3    Senior Developer                 8                  15          65,000
# 4   Software Engineer                 1                   4           86000
#
#   Signing Bonus Annual Bonus Annual Stock Value/Bonus Gender  \
# 0           NaN          NaN                      NaN   Male
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3777 entries, 0 to 3776
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Timestamp                 3777 non-null   object
#  1   Employer                  2004 non-null   object
#  2   Location                  3259 non-null   object
#  3   Job Title                 3776 non-null   object
#  4   Years at Employer         3396 non-null   object
#  5   Years of Experience       3442 non-null   object
#  6   Annual Base Pay           3776 non-null   object
#  7   Signing Bonus             2496 non-null   object
#  8   Annual Bonus              2661 non-null   object
#  9   Annual Stock Value/Bonus  2238 non-null   object
#  10  Gender                    3587 non-null   object
#  11  Additional Comments       528 non-null    object
# dtypes: object(12)
# memory usage: 354.2+ KB

# %%
df3.rename(columns = {'Years of Experience':'YearsExperience'}, inplace = True)

# %%
df3.rename(columns = {'Annual Base Pay':'Salary'}, inplace = True)

# %%
df3.rename(columns = {'Job Title':'Job_title'}, inplace = True)

# %%
df3.head()
# Out:
#             Timestamp            Employer           Location  \
# 0  3/21/2016 12:54:49                 NaN        Raleigh, NC
# 1  3/21/2016 12:58:52              Opower  San Francisco, CA
# 2  3/21/2016 12:58:57                 NaN       San Diego CA
# 3  3/21/2016 12:58:58             Walmart    Bentonville, AR
# 4  3/21/2016 12:59:11  Vertical Knowledge      Cleveland, OH
#
#             Job_title Years at Employer  YearsExperience  Salary  \
# 0  Software Developer               NaN               18  122000
# 1    Systems Engineer                 2               13  125000
# 2    Systems engineer                 1  1 of employment  83,000
# 3    Senior Developer                 8               15  65,000
# 4   Software Engineer                 1                4   86000
#
#   Signing Bonus Annual Bonus Annual Stock Value/Bonus Gender  \
# 0           NaN          NaN                      NaN   Male
# 1          5000            0              5000 shares   Male
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4404 entries, 0 to 4403
# Data columns (total 27 columns):
#  #   Column                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                        4404 non-null   object
#  1   Employment Type                                                                                                                                                  4404 non-null   object
# ...

# %%
df2.rename(columns = {'Job Title In Company':'Job_title'}, inplace = True)

# %%
df2.rename(columns = {'Total Base Salary in 2018 (in USD)':'Salay'}, inplace = True)

# %%
df2.rename(columns = {'Years Experience in Industry':'YearsExperience'}, inplace = True)

# %%
df2["Location"] = df2["Primary Location (City)"] +','+ df2["Primary Location (Country)"]

# %%
df2.head()
# Out:
#            Timestamp Employment Type     Company Name  \
# 0  9/11/2019 0:47:40       Full-time             Citi
# 1  9/11/2019 0:51:26       Full-time              Ibm
# 2  9/11/2019 0:51:56       Full-time        No Answer
# 3  9/11/2019 0:52:28       Full-time    Td ameritrade
# 4  9/11/2019 0:54:02       Full-time  The Table Times
#
#   Company Size - # Employees Primary Location (Country)  \
# 0             10,000-100,000         United States (US)
# 1             10,000-100,000         United States (US)
# 2             10,000-100,000             Australia (AU)
# 3               1,000-10,000         United States (US)
# 4                     20-100         United States (US)
#
#   Primary Location (City)         Industry in Company  \
# 0               Manhattan                     Finance
# 1                     NaN                    Software
# 2                     NaN         General Engineering
# 3               Ann arbor             Web Development
# ...

# %%
df.rename(columns = {'Job title':'Job_title'}, inplace = True)

# %%
df.rename(columns = {'What is your annual salary?':'Salary'}, inplace = True)

# %%
df.rename(columns = {'Where are you located? (City/state/country)':'Location'}, inplace = True)

# %%
df.rename(columns = {'How many years of post-college professional work experience do you have?':'YearsExperience'}, inplace = True)

# %%
df.head()
# Out:
#             Timestamp How old are you? What industry do you work in?  \
# 0  4/24/2019 11:43:21            35-44                    Government
# 1  4/24/2019 11:43:26            25-34       Environmental nonprofit
# 2  4/24/2019 11:43:27            18-24               Market Research
# 3  4/24/2019 11:43:27            25-34                 Biotechnology
# 4  4/24/2019 11:43:29            25-34                    Healthcare
#
#                                   Job_title  Salary  \
# 0          Talent Management Asst. Director   75000
# 1                       Operations Director  65,000
# 2                 Market Research Assistant  36,330
# 3                          Senior Scientist   34600
# 4  Social worker (embedded in primary care)   55000
#
#   Please indicate the currency                 Location YearsExperience  \
# 0                          USD            Nashville, TN   11 - 20 years
# 1                          USD              Madison, Wi    8 - 10 years
# ...

# %%
frames = [df, df2, df3]
data = pd.concat(frames)

# %%
data.head()
# Out:
#             Timestamp How old are you? What industry do you work in?  \
# 0  4/24/2019 11:43:21            35-44                    Government
# 1  4/24/2019 11:43:26            25-34       Environmental nonprofit
# 2  4/24/2019 11:43:27            18-24               Market Research
# 3  4/24/2019 11:43:27            25-34                 Biotechnology
# 4  4/24/2019 11:43:29            25-34                    Healthcare
#
#                                   Job_title  Salary  \
# 0          Talent Management Asst. Director   75000
# 1                       Operations Director  65,000
# 2                 Market Research Assistant  36,330
# 3                          Senior Scientist   34600
# 4  Social worker (embedded in primary care)   55000
#
#   Please indicate the currency                 Location YearsExperience  \
# 0                          USD            Nashville, TN   11 - 20 years
# 1                          USD              Madison, Wi    8 - 10 years
# ...

# %%
data = data[["Job_title", "Salary","Location","YearsExperience"]]

# %%
data.head(50)
# Out:
#                                      Job_title      Salary  \
# 0             Talent Management Asst. Director       75000
# 1                          Operations Director      65,000
# 2                    Market Research Assistant      36,330
# 3                             Senior Scientist       34600
# 4     Social worker (embedded in primary care)       55000
# 5                         Associate Consultant      45,000
# 6                          Development Manager      51,000
# 7                  Student Records Coordinator      54,371
# 8                                     Director       45000
# 9                                   Copywriter       80000
# 10                              office manager      72,000
# 11           HR and Administrative Coordinator      50,000
# 12                           Marketing Manager     73 000$
# 13                   Senior research executive      30,000
# 14                                     Teacher       54000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42555 entries, 0 to 3776
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job_title        42552 non-null  object
#  1   Salary           38147 non-null  object
#  2   Location         39027 non-null  object
#  3   YearsExperience  42220 non-null  object
# dtypes: object(4)
# memory usage: 1.6+ MB

# %%
with open('data.txt', 'w') as f:
    for row in  data.to_dict('records'):
        f.write(json.dumps(row) + '\n')
